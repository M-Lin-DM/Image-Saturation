# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
noise_img = np.random.rand(100, 100, 3)
plt.axis('off')
plt.imshow(noise_img)

# Save the image to a file
save_path = r"C:\Users\MrLin\OneDrive\COMPLEX OBJECTS\PROJECTS\SATURATION\JUPYTER NOTEBOOK\movies\noise"

plt.savefig(f'{save_path}\\noise.png', bbox_inches='tight', pad_inches=0, dpi=300)
